# %%
## imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Data Exploration and Cleaning

# %%
## loading in the training data
## original df

train_ames = pd.read_csv('../data/train.csv')
train_ames.head()
# Out:
#     Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL           NaN     13517   Pave   NaN
# 1  544  531379050           60        RL          43.0     11492   Pave   NaN
# 2  153  535304180           20        RL          68.0      7922   Pave   NaN
# 3  318  916386060           60        RL          73.0      9802   Pave   NaN
# 4  255  906425045           50        RL          82.0     14235   Pave   NaN
#
#   Lot Shape Land Contour  ... Screen Porch Pool Area Pool QC Fence  \
# 0       IR1          Lvl  ...            0         0     NaN   NaN
# 1       IR1          Lvl  ...            0         0     NaN   NaN
# 2       Reg          Lvl  ...            0         0     NaN   NaN
# 3       Reg          Lvl  ...            0         0     NaN   NaN
# 4       IR1          Lvl  ...            0         0     NaN   NaN
#
#   Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  SalePrice
# 0          NaN        0       3    2010        WD      130500
# 1          NaN        0       4    2009        WD      220000
# 2          NaN        0       1    2010        WD      109000
# 3          NaN        0       4    2010        WD      174000
# 4          NaN        0       3    2010        WD      138500
#
# [5 rows x 81 columns]

# %%
## loading in testing data
## original df
test_ames = pd.read_csv("../data/test.csv")
test_ames.head()
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   Alley Lot Shape Land Contour  ... 3Ssn Porch Screen Porch Pool Area Pool QC  \
# 0  Grvl       Reg          Lvl  ...          0            0         0     NaN
# 1   NaN       IR1          Lvl  ...          0            0         0     NaN
# 2   NaN       IR1          Lvl  ...          0            0         0     NaN
# 3   NaN       Reg          Lvl  ...          0            0         0     NaN
# 4   NaN       IR1          Lvl  ...          0          185         0     NaN
#
#   Fence Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type
# 0   NaN          NaN        0       4     2006        WD
# 1   NaN          NaN        0       8     2006        WD
# 2   NaN          NaN        0       9     2006        New
# 3   NaN          NaN        0       7     2007        WD
# 4   NaN          NaN        0       7     2009        WD
#
# [5 rows x 80 columns]

# %%
train_ames.shape
# Out:
# (2051, 81)

# %%
test_ames.shape
# Out:
# (878, 80)

# %%
### What column is in train that is not in test set?

set(train_ames) - set(test_ames)
# Out:
# {'SalePrice'}

# %%
## set Id column to be our new index for both training and test
train_ames.set_index("Id", inplace=True)
test_ames.set_index("Id", inplace=True)

# %% [markdown]
# #### Checking for missing values

# %%
## checking for null values in training set
train_ames.isnull().sum().sort_values(ascending=False)
# Out:
# Pool QC         2042
# Misc Feature    1986
# Alley           1911
# Fence           1651
# Fireplace Qu    1000
#                 ...
# Central Air        0
# Electrical         0
# 1st Flr SF         0
# 2nd Flr SF         0
# SalePrice          0
# Length: 80, dtype: int64

# %%
## there are too many columns to see which columns are missing values
## creating a function that shows exactly which columns have missing values
def missing_values(df):
    lst = []
    for column in df.columns:
        if df[column].isnull().sum() > 0:
            lst.append(column)
    return lst

# %%
missing_values(train_ames)
# Out:
# ['Lot Frontage',
#  'Alley',
#  'Mas Vnr Type',
#  'Mas Vnr Area',
#  'Bsmt Qual',
#  'Bsmt Cond',
#  'Bsmt Exposure',
#  'BsmtFin Type 1',
#  'BsmtFin SF 1',
#  'BsmtFin Type 2',
#  'BsmtFin SF 2',
#  'Bsmt Unf SF',
#  'Total Bsmt SF',
#  'Bsmt Full Bath',
#  'Bsmt Half Bath',
#  'Fireplace Qu',
#  'Garage Type',
#  'Garage Yr Blt',
#  'Garage Finish',
#  'Garage Cars',
#  'Garage Area',
#  'Garage Qual',
#  'Garage Cond',
#  'Pool QC',
#  'Fence',
#  'Misc Feature']

# %%
## another way to check for missing values
train_ames.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2051 entries, 109 to 10
# Data columns (total 80 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   PID              2051 non-null   int64
#  1   MS SubClass      2051 non-null   int64
#  2   MS Zoning        2051 non-null   object
#  3   Lot Frontage     1721 non-null   float64
#  4   Lot Area         2051 non-null   int64
#  5   Street           2051 non-null   object
#  6   Alley            140 non-null    object
#  7   Lot Shape        2051 non-null   object
#  8   Land Contour     2051 non-null   object
#  9   Utilities        2051 non-null   object
#  10  Lot Config       2051 non-null   object
#  11  Land Slope       2051 non-null   object
#  12  Neighborhood     2051 non-null   object
#  13  Condition 1      2051 non-null   object
#  14  Condition 2      2051 non-null   object
#  15  Bldg Type        2051 non-null   object
#  16  House Style      2051 non-null   object
#  17  Overall Qual     2051 non-null   int64
#  18  Overall Cond     2051 non-null   int64
#  19  Year Built       2051 non-null   int64
#  20  Year Remod/Add   2051 non-null   int64
#  21  Roof Style       2051 non-null   object
#  22  Roof Matl        2051 non-null   object
#  23  Exterior 1st     2051 non-null   object
#  24  Exterior 2nd     2051 non-null   object
#  25  Mas Vnr Type     2029 non-null   object
#  26  Mas Vnr Area     2029 non-null   float64
#  27  Exter Qual       2051 non-null   object
#  28  Exter Cond       2051 non-null   object
#  29  Foundation       2051 non-null   object
#  30  Bsmt Qual        1996 non-null   object
#  31  Bsmt Cond        1996 non-null   object
#  32  Bsmt Exposure    1993 non-null   object
#  33  BsmtFin Type 1   1996 non-null   object
#  34  BsmtFin SF 1     2050 non-null   float64
#  35  BsmtFin Type 2   1995 non-null   object
#  36  BsmtFin SF 2     2050 non-null   float64
#  37  Bsmt Unf SF      2050 non-null   float64
#  38  Total Bsmt SF    2050 non-null   float64
#  39  Heating          2051 non-null   object
#  40  Heating QC       2051 non-null   object
#  41  Central Air      2051 non-null   object
#  42  Electrical       2051 non-null   object
#  43  1st Flr SF       2051 non-null   int64
#  44  2nd Flr SF       2051 non-null   int64
#  45  Low Qual Fin SF  2051 non-null   int64
#  46  Gr Liv Area      2051 non-null   int64
#  47  Bsmt Full Bath   2049 non-null   float64
#  48  Bsmt Half Bath   2049 non-null   float64
#  49  Full Bath        2051 non-null   int64
#  50  Half Bath        2051 non-null   int64
#  51  Bedroom AbvGr    2051 non-null   int64
#  52  Kitchen AbvGr    2051 non-null   int64
#  53  Kitchen Qual     2051 non-null   object
#  54  TotRms AbvGrd    2051 non-null   int64
#  55  Functional       2051 non-null   object
#  56  Fireplaces       2051 non-null   int64
#  57  Fireplace Qu     1051 non-null   object
#  58  Garage Type      1938 non-null   object
#  59  Garage Yr Blt    1937 non-null   float64
#  60  Garage Finish    1937 non-null   object
#  61  Garage Cars      2050 non-null   float64
#  62  Garage Area      2050 non-null   float64
#  63  Garage Qual      1937 non-null   object
#  64  Garage Cond      1937 non-null   object
#  65  Paved Drive      2051 non-null   object
#  66  Wood Deck SF     2051 non-null   int64
#  67  Open Porch SF    2051 non-null   int64
#  68  Enclosed Porch   2051 non-null   int64
#  69  3Ssn Porch       2051 non-null   int64
#  70  Screen Porch     2051 non-null   int64
#  71  Pool Area        2051 non-null   int64
#  72  Pool QC          9 non-null      object
#  73  Fence            400 non-null    object
#  74  Misc Feature     65 non-null     object
#  75  Misc Val         2051 non-null   int64
#  76  Mo Sold          2051 non-null   int64
#  77  Yr Sold          2051 non-null   int64
#  78  Sale Type        2051 non-null   object
#  79  SalePrice        2051 non-null   int64
# dtypes: float64(11), int64(27), object(42)
# memory usage: 1.3+ MB

# %% [markdown]
# ### Processing numeric data

# %%
### creating a dataframe containing only the numeric data
numeric_df = train_ames._get_numeric_data()
numeric_df.head()
# Out:
#            PID  MS SubClass  Lot Frontage  Lot Area  Overall Qual  \
# Id
# 109  533352170           60           NaN     13517             6
# 544  531379050           60          43.0     11492             7
# 153  535304180           20          68.0      7922             5
# 318  916386060           60          73.0      9802             5
# 255  906425045           50          82.0     14235             6
#
#      Overall Cond  Year Built  Year Remod/Add  Mas Vnr Area  BsmtFin SF 1  \
# Id
# 109             8        1976            2005         289.0         533.0
# 544             5        1996            1997         132.0         637.0
# 153             7        1953            2007           0.0         731.0
# 318             5        2006            2007           0.0           0.0
# 255             8        1900            1993           0.0           0.0
#
#      ...  Wood Deck SF  Open Porch SF  Enclosed Porch  3Ssn Porch  \
# Id   ...
# 109  ...             0             44               0           0
# 544  ...             0             74               0           0
# 153  ...             0             52               0           0
# 318  ...           100              0               0           0
# 255  ...             0             59               0           0
#
#      Screen Porch  Pool Area  Misc Val  Mo Sold  Yr Sold  SalePrice
# Id
# 109             0          0         0        3     2010     130500
# 544             0          0         0        4     2009     220000
# 153             0          0         0        1     2010     109000
# 318             0          0         0        4     2010     174000
# 255             0          0         0        3     2010     138500
#
# [5 rows x 38 columns]

# %%
plt.figure(figsize = (30,16))
corr = numeric_df.corr()

# Set up mask to be "True" in the upper triangle.
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
sns.heatmap(corr, mask = mask, square = True, annot = True, linewidth=0.05, vmin=0, vmax=1);

# %%
## Correlaton matrix for sale price column
plt.figure(figsize = (9,9))
sale_corr = numeric_df.corr()[['SalePrice']].sort_values('SalePrice')
sns.heatmap(sale_corr, annot = True, linewidth = 0.05, vmin = 0, vmax = 1);

# %%
## creating a seperate df for all of the numeric features I will use in the model
## only using corr values greater than 0.50
feats = ['Overall Qual', 'Year Built', 'Year Remod/Add', 'Mas Vnr Area', 'Total Bsmt SF', '1st Flr SF','Gr Liv Area', 
         'Full Bath','TotRms AbvGrd', 'Garage Yr Blt', 'Garage Cars', 'Garage Area', 'SalePrice']
final_num_features = numeric_df[feats].copy()

# %%
final_num_features.head()
# Out:
#      Overall Qual  Year Built  Year Remod/Add  Mas Vnr Area  Total Bsmt SF  \
# Id
# 109             6        1976            2005         289.0          725.0
# 544             7        1996            1997         132.0          913.0
# 153             5        1953            2007           0.0         1057.0
# 318             5        2006            2007           0.0          384.0
# 255             6        1900            1993           0.0          676.0
#
#      1st Flr SF  Gr Liv Area  Full Bath  TotRms AbvGrd  Garage Yr Blt  \
# Id
# 109         725         1479          2              6         1976.0
# 544         913         2122          2              8         1997.0
# 153        1057         1057          1              5         1953.0
# 318         744         1444          2              7         2007.0
# 255         831         1445          2              6         1957.0
#
#      Garage Cars  Garage Area  SalePrice
# Id
# 109          2.0        475.0     130500
# 544          2.0        559.0     220000
# 153          1.0        246.0     109000
# 318          2.0        400.0     174000
# 255          2.0        484.0     138500

# %% [markdown]
# Fixing column names

# %%
## making column names lowercase
final_num_features.columns = map(str.lower, final_num_features.columns)

## replacing whitespace with underscore in column name
final_num_features.columns = final_num_features.columns.str.replace(' ','_')

# %% [markdown]
# #### Outliers

# %%
final_num_features.describe()
# Out:
#        overall_qual   year_built  year_remod/add  mas_vnr_area  total_bsmt_sf  \
# count   2051.000000  2051.000000     2051.000000   2029.000000    2050.000000
# mean       6.112140  1971.708922     1984.190151     99.695909    1057.987805
# std        1.426271    30.177889       21.036250    174.963129     449.410704
# min        1.000000  1872.000000     1950.000000      0.000000       0.000000
# 25%        5.000000  1953.500000     1964.500000      0.000000     793.000000
# 50%        6.000000  1974.000000     1993.000000      0.000000     994.500000
# 75%        7.000000  2001.000000     2004.000000    161.000000    1318.750000
# max       10.000000  2010.000000     2010.000000   1600.000000    6110.000000
#
#         1st_flr_sf  gr_liv_area    full_bath  totrms_abvgrd  garage_yr_blt  \
# count  2051.000000  2051.000000  2051.000000    2051.000000    1937.000000
# mean   1164.488055  1499.330083     1.577279       6.435885    1978.707796
# std     396.446923   500.447829     0.549279       1.560225      25.441094
# min     334.000000   334.000000     0.000000       2.000000    1895.000000
# 25%     879.500000  1129.000000     1.000000       5.000000    1961.000000
# 50%    1093.000000  1444.000000     2.000000       6.000000    1980.000000
# 75%    1405.000000  1728.500000     2.000000       7.000000    2002.000000
# max    5095.000000  5642.000000     4.000000      15.000000    2207.000000
#
#        garage_cars  garage_area      saleprice
# count  2050.000000  2050.000000    2051.000000
# mean      1.776585   473.671707  181469.701609
# std       0.764537   215.934561   79258.659352
# min       0.000000     0.000000   12789.000000
# 25%       1.000000   319.000000  129825.000000
# 50%       2.000000   480.000000  162500.000000
# 75%       2.000000   576.000000  214000.000000
# max       5.000000  1418.000000  611657.000000

# %%
## checking for outliers visually before I take care of missing values 
sns.pairplot(data=final_num_features, y_vars =['saleprice'], x_vars = ['overall_qual', 'year_built', 'year_remod/add', 'mas_vnr_area',
       'total_bsmt_sf', '1st_flr_sf', 'gr_liv_area', 'full_bath',
       'totrms_abvgrd', 'garage_yr_blt', 'garage_cars', 'garage_area'], 
        kind='reg');

# %% [markdown]
# **Notes:** There are outliers in garage_yr_blt, gr_living_area, first_flr_sf, and total_bsmt_sf. I will take a look at those columns below

# %% [markdown]
# Garage Year Built

# %%
final_num_features[ final_num_features ['garage_yr_blt'] == 2207 ] 
## because garage_yr_blt has only one outlier and I don't necessarily need this one data point, I will drop this row. 
## I will have to drop this same row in the test set
# Out:
#       overall_qual  year_built  year_remod/add  mas_vnr_area  total_bsmt_sf  \
# Id
# 2261             8        2006            2007           NaN         1546.0
#
#       1st_flr_sf  gr_liv_area  full_bath  totrms_abvgrd  garage_yr_blt  \
# Id
# 2261        1564         1564          2              6         2207.0
#
#       garage_cars  garage_area  saleprice
# Id
# 2261          2.0        502.0     267300

# %%
final_num_features.drop(index=2261, axis = 0, inplace=True)

# %% [markdown]
# Garage Living Area

# %%
final_num_features[final_num_features['gr_liv_area'] > 4000]
## these two outliers I am going to delete. will also delete these in the test set
# Out:
#       overall_qual  year_built  year_remod/add  mas_vnr_area  total_bsmt_sf  \
# Id
# 1499            10        2008            2008         796.0         6110.0
# 2181            10        2008            2009        1224.0         5095.0
#
#       1st_flr_sf  gr_liv_area  full_bath  totrms_abvgrd  garage_yr_blt  \
# Id
# 1499        4692         5642          2             12         2008.0
# 2181        5095         5095          2             15         2008.0
#
#       garage_cars  garage_area  saleprice
# Id
# 1499          2.0       1418.0     160000
# 2181          3.0       1154.0     183850

# %%
final_num_features.drop(index =[1499,2181], axis = 0, inplace=True)

# %% [markdown]
# deleting the three outliers above gets rid of the other outliers in total_bsmt_sf and first_fl_sf

# %% [markdown]
# ### Imputing Missing Values

# %%
final_num_features.head()
# Out:
#      overall_qual  year_built  year_remod/add  mas_vnr_area  total_bsmt_sf  \
# Id
# 109             6        1976            2005         289.0          725.0
# 544             7        1996            1997         132.0          913.0
# 153             5        1953            2007           0.0         1057.0
# 318             5        2006            2007           0.0          384.0
# 255             6        1900            1993           0.0          676.0
#
#      1st_flr_sf  gr_liv_area  full_bath  totrms_abvgrd  garage_yr_blt  \
# Id
# 109         725         1479          2              6         1976.0
# 544         913         2122          2              8         1997.0
# 153        1057         1057          1              5         1953.0
# 318         744         1444          2              7         2007.0
# 255         831         1445          2              6         1957.0
#
#      garage_cars  garage_area  saleprice
# Id
# 109          2.0        475.0     130500
# 544          2.0        559.0     220000
# 153          1.0        246.0     109000
# 318          2.0        400.0     174000
# 255          2.0        484.0     138500

# %%
missing_values(final_num_features)
# Out:
# ['mas_vnr_area',
#  'total_bsmt_sf',
#  'garage_yr_blt',
#  'garage_cars',
#  'garage_area']

# %%
final_num_features['mas_vnr_area'].isnull().sum()
# Out:
# 21

# %%
mean_mas_vnr = final_num_features['mas_vnr_area'].mean()

# %%
final_num_features['total_bsmt_sf'].isnull().sum()
# Out:
# 1

# %%
mean_ttl_bsmt = final_num_features['total_bsmt_sf'].mean()

# %%
final_num_features['garage_yr_blt'].isnull().sum()
# Out:
# 114

# %%
mean_grg_yr = final_num_features['garage_yr_blt'].mean()

# %%
final_num_features['garage_cars'].isnull().sum()
# Out:
# 1

# %%
mean_garg_car = final_num_features['garage_cars'].mean()

# %%
final_num_features['garage_area'].isnull().sum()
# Out:
# 1

# %%
mean_grg_area = final_num_features['garage_area'].mean()

# %%
final_num_features['mas_vnr_area'].fillna(mean_mas_vnr, inplace=True)
final_num_features['total_bsmt_sf'].fillna(mean_ttl_bsmt, inplace=True)
final_num_features['garage_yr_blt'].fillna(mean_grg_yr, inplace=True)
final_num_features['garage_cars'].fillna(mean_garg_car, inplace=True)
final_num_features['garage_area'].fillna(mean_grg_area, inplace=True)

# %% [markdown]
# ### Categorical Data

# %%
## creating a seperate dataframe for categorical columns
total_columns = train_ames.columns
numeric_columns = train_ames._get_numeric_data().columns

cat_features = list(set(total_columns) - set(numeric_columns))

categorical_df = train_ames[cat_features].copy()

# %%
categorical_df.head()
# Out:
#     Bsmt Qual Land Contour Lot Config Lot Shape Heating MS Zoning  \
# Id
# 109        TA          Lvl    CulDSac       IR1    GasA        RL
# 544        Gd          Lvl    CulDSac       IR1    GasA        RL
# 153        TA          Lvl     Inside       Reg    GasA        RL
# 318        Gd          Lvl     Inside       Reg    GasA        RL
# 255        Fa          Lvl     Inside       IR1    GasA        RL
#
#     BsmtFin Type 2 Sale Type Electrical Roof Matl  ... Misc Feature  \
# Id                                                 ...
# 109            Unf       WD       SBrkr   CompShg  ...          NaN
# 544            Unf       WD       SBrkr   CompShg  ...          NaN
# 153            Unf       WD       SBrkr   CompShg  ...          NaN
# 318            Unf       WD       SBrkr   CompShg  ...          NaN
# 255            Unf       WD       SBrkr   CompShg  ...          NaN
#
#     Garage Type Land Slope Exter Cond Fence Heating QC Garage Qual  \
# Id
# 109      Attchd        Gtl         TA   NaN         Ex          TA
# 544      Attchd        Gtl         TA   NaN         Ex          TA
# 153      Detchd        Gtl         Gd   NaN         TA          TA
# 318     BuiltIn        Gtl         TA   NaN         Gd          TA
# 255      Detchd        Gtl         TA   NaN         TA          TA
#
#     Condition 2 Condition 1 BsmtFin Type 1
# Id
# 109        Norm        RRAe            GLQ
# 544        Norm        Norm            GLQ
# 153        Norm        Norm            GLQ
# 318        Norm        Norm            Unf
# 255        Norm        Norm            Unf
#
# [5 rows x 42 columns]

# %%
categorical_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2051 entries, 109 to 10
# Data columns (total 42 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Bsmt Qual       1996 non-null   object
#  1   Land Contour    2051 non-null   object
#  2   Lot Config      2051 non-null   object
#  3   Lot Shape       2051 non-null   object
#  4   Heating         2051 non-null   object
#  5   MS Zoning       2051 non-null   object
#  6   BsmtFin Type 2  1995 non-null   object
#  7   Sale Type       2051 non-null   object
#  8   Electrical      2051 non-null   object
#  9   Roof Matl       2051 non-null   object
#  10  Foundation      2051 non-null   object
#  11  Neighborhood    2051 non-null   object
#  12  Functional      2051 non-null   object
#  13  Bsmt Cond       1996 non-null   object
#  14  Bldg Type       2051 non-null   object
#  15  Exter Qual      2051 non-null   object
#  16  Central Air     2051 non-null   object
#  17  Bsmt Exposure   1993 non-null   object
#  18  Alley           140 non-null    object
#  19  Garage Finish   1937 non-null   object
#  20  Utilities       2051 non-null   object
#  21  Street          2051 non-null   object
#  22  Pool QC         9 non-null      object
#  23  Exterior 1st    2051 non-null   object
#  24  Exterior 2nd    2051 non-null   object
#  25  Roof Style      2051 non-null   object
#  26  Garage Cond     1937 non-null   object
#  27  House Style     2051 non-null   object
#  28  Mas Vnr Type    2029 non-null   object
#  29  Fireplace Qu    1051 non-null   object
#  30  Kitchen Qual    2051 non-null   object
#  31  Paved Drive     2051 non-null   object
#  32  Misc Feature    65 non-null     object
#  33  Garage Type     1938 non-null   object
#  34  Land Slope      2051 non-null   object
#  35  Exter Cond      2051 non-null   object
#  36  Fence           400 non-null    object
#  37  Heating QC      2051 non-null   object
#  38  Garage Qual     1937 non-null   object
#  39  Condition 2     2051 non-null   object
#  40  Condition 1     2051 non-null   object
#  41  BsmtFin Type 1  1996 non-null   object
# dtypes: object(42)
# memory usage: 753.5+ KB

# %%
## visualization between cat variables and sale price
plt.figure(figsize=(16,9))
ax= sns.barplot(x=categorical_df['Neighborhood'], y=final_num_features['saleprice'])
ax.set_xticklabels(ax.get_xticklabels(),rotation = 30);

# %%
def box_visual(col_name):
    plt.figure(figsize=(9,9))
    ax= sns.barplot(x=categorical_df[col_name], y=final_num_features['saleprice'])
    ax.set_xticklabels(ax.get_xticklabels(),rotation = 30)
    return ax;

# %%
box_visual('Kitchen Qual');

# %%
box_visual('Condition 1');

# %%
box_visual('Condition 2');

# %%
box_visual('Garage Qual');

# %%
box_visual('Exter Qual');

# %%
box_visual('Exter Cond');

# %%
## encoding only some of the categorical variables
## renaming only the columns that I'm going to encode

categorical_df.columns = map(str.lower, categorical_df.columns)
categorical_df.columns = categorical_df.columns.str.replace(' ','_')

# %%
cat_subset_df = categorical_df[['kitchen_qual', 'exter_qual', 'exter_cond','garage_qual','condition_1', 'neighborhood']]

# %%
cat_subset_df.head()
# Out:
#     kitchen_qual exter_qual exter_cond garage_qual condition_1 neighborhood
# Id
# 109           Gd         Gd         TA          TA        RRAe       Sawyer
# 544           Gd         Gd         TA          TA        Norm      SawyerW
# 153           Gd         TA         Gd          TA        Norm        NAmes
# 318           TA         TA         TA          TA        Norm       Timber
# 255           TA         TA         TA          TA        Norm      SawyerW

# %%
cat_subset_df = pd.get_dummies(cat_subset_df, drop_first = True)

# %% [markdown]
# #### Joining the numerica dataframe with the dummy encoded cat dataframe

# %%
complete_train_df = final_num_features.join(cat_subset_df)

# %%
complete_train_df.head()
# Out:
#      overall_qual  year_built  year_remod/add  mas_vnr_area  total_bsmt_sf  \
# Id
# 109             6        1976            2005         289.0          725.0
# 544             7        1996            1997         132.0          913.0
# 153             5        1953            2007           0.0         1057.0
# 318             5        2006            2007           0.0          384.0
# 255             6        1900            1993           0.0          676.0
#
#      1st_flr_sf  gr_liv_area  full_bath  totrms_abvgrd  garage_yr_blt  ...  \
# Id                                                                     ...
# 109         725         1479          2              6         1976.0  ...
# 544         913         2122          2              8         1997.0  ...
# 153        1057         1057          1              5         1953.0  ...
# 318         744         1444          2              7         2007.0  ...
# 255         831         1445          2              6         1957.0  ...
#
#      neighborhood_NoRidge  neighborhood_NridgHt  neighborhood_OldTown  \
# Id
# 109                     0                     0                     0
# 544                     0                     0                     0
# 153                     0                     0                     0
# 318                     0                     0                     0
# 255                     0                     0                     0
#
#      neighborhood_SWISU  neighborhood_Sawyer  neighborhood_SawyerW  \
# Id
# 109                   0                    1                     0
# 544                   0                    0                     1
# 153                   0                    0                     0
# 318                   0                    0                     0
# 255                   0                    0                     1
#
#      neighborhood_Somerst  neighborhood_StoneBr  neighborhood_Timber  \
# Id
# 109                     0                     0                    0
# 544                     0                     0                    0
# 153                     0                     0                    0
# 318                     0                     0                    1
# 255                     0                     0                    0
#
#      neighborhood_Veenker
# Id
# 109                     0
# 544                     0
# 153                     0
# 318                     0
# 255                     0
#
# [5 rows x 62 columns]

# %% [markdown]
# ### Cleaning the testing data

# %%
test_ames.head()
# Out:
#             PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street Alley  \
# Id
# 2658  902301120          190        RM          69.0      9142   Pave  Grvl
# 2718  905108090           90        RL           NaN      9662   Pave   NaN
# 2414  528218130           60        RL          58.0     17104   Pave   NaN
# 1989  902207150           30        RM          60.0      8520   Pave   NaN
# 625   535105100           20        RL           NaN      9500   Pave   NaN
#
#      Lot Shape Land Contour Utilities  ... 3Ssn Porch Screen Porch Pool Area  \
# Id                                     ...
# 2658       Reg          Lvl    AllPub  ...          0            0         0
# 2718       IR1          Lvl    AllPub  ...          0            0         0
# 2414       IR1          Lvl    AllPub  ...          0            0         0
# 1989       Reg          Lvl    AllPub  ...          0            0         0
# 625        IR1          Lvl    AllPub  ...          0          185         0
#
#      Pool QC Fence Misc Feature Misc Val  Mo Sold  Yr Sold  Sale Type
# Id
# 2658     NaN   NaN          NaN        0        4     2006        WD
# 2718     NaN   NaN          NaN        0        8     2006        WD
# 2414     NaN   NaN          NaN        0        9     2006        New
# 1989     NaN   NaN          NaN        0        7     2007        WD
# 625      NaN   NaN          NaN        0        7     2009        WD
#
# [5 rows x 79 columns]

# %% [markdown]
# Fixing column names

# %%
## making column names lowercase
test_ames.columns = map(str.lower, test_ames.columns)

## replacing whitespace with underscore in column name
test_ames.columns = test_ames.columns.str.replace(' ','_')

# %% [markdown]
# #### Creating a df with the same features as the training set

# %%
feats = ['overall_qual', 'year_built', 'year_remod/add', 'mas_vnr_area',
       'total_bsmt_sf', '1st_flr_sf', 'gr_liv_area', 'full_bath',
       'totrms_abvgrd', 'garage_yr_blt', 'garage_cars', 'garage_area', 'kitchen_qual', 
         'exter_qual', 'exter_cond','garage_qual','condition_1', 'neighborhood']

# %%
test_df = test_ames[feats].copy()

test_df.head()
# Out:
#       overall_qual  year_built  year_remod/add  mas_vnr_area  total_bsmt_sf  \
# Id
# 2658             6        1910            1950           0.0           1020
# 2718             5        1977            1977           0.0           1967
# 2414             7        2006            2006           0.0            654
# 1989             5        1923            2006           0.0            968
# 625              6        1963            1963         247.0           1394
#
#       1st_flr_sf  gr_liv_area  full_bath  totrms_abvgrd  garage_yr_blt  \
# Id
# 2658         908         1928          2              9         1910.0
# 2718        1967         1967          2             10         1977.0
# 2414         664         1496          2              7         2006.0
# 1989         968          968          1              5         1935.0
# 625         1394         1394          1              6         1963.0
#
#       garage_cars  garage_area kitchen_qual exter_qual exter_cond garage_qual  \
# Id
# 2658            1          440           Fa         TA         Fa          Po
# 2718            2          580           TA         TA         TA          TA
# 2414            2          426           Gd         Gd         TA          TA
# 1989            2          480           TA         Gd         TA          Fa
# 625             2          514           TA         TA         TA          TA
#
#      condition_1 neighborhood
# Id
# 2658        Norm      OldTown
# 2718        Norm       Sawyer
# 2414        Norm      Gilbert
# 1989        Norm      OldTown
# 625         Norm        NAmes

# %%
test_df.describe()
# Out:
#        overall_qual   year_built  year_remod/add  mas_vnr_area  total_bsmt_sf  \
# count    878.000000   878.000000      878.000000    877.000000     878.000000
# mean       6.050114  1970.492027     1984.417995    106.236032    1034.357631
# std        1.369065    30.395895       20.450725    187.158908     413.446291
# min        2.000000  1880.000000     1950.000000      0.000000       0.000000
# 25%        5.000000  1954.000000     1967.000000      0.000000     789.000000
# 50%        6.000000  1972.000000     1992.000000      0.000000     975.000000
# 75%        7.000000  1999.750000     2003.000000    172.000000    1247.000000
# max       10.000000  2010.000000     2010.000000   1378.000000    2630.000000
#
#         1st_flr_sf  gr_liv_area   full_bath  totrms_abvgrd  garage_yr_blt  \
# count   878.000000   878.000000  878.000000     878.000000     833.000000
# mean   1145.787016  1496.914579    1.539863       6.454442    1976.759904
# std     375.264111   506.468967    0.559060       1.596632      25.689763
# min     407.000000   407.000000    0.000000       3.000000    1900.000000
# 25%     864.000000  1114.000000    1.000000       5.000000    1960.000000
# 50%    1063.000000  1436.000000    2.000000       6.000000    1978.000000
# 75%    1358.000000  1779.000000    2.000000       7.000000    2001.000000
# max    2674.000000  4476.000000    4.000000      12.000000    2010.000000
#
#        garage_cars  garage_area
# count   878.000000   878.000000
# mean      1.742597   470.362187
# std       0.750391   212.734075
# min       0.000000     0.000000
# 25%       1.000000   322.500000
# 50%       2.000000   473.000000
# 75%       2.000000   576.000000
# max       4.000000  1488.000000

# %%
## deleting rows where the garage living area is above 4000
test_df[test_df['gr_liv_area'] > 4000]
# Out:
#       overall_qual  year_built  year_remod/add  mas_vnr_area  total_bsmt_sf  \
# Id
# 1761            10        1996            1996           0.0           2396
# 1768            10        1994            1995        1170.0           2444
#
#       1st_flr_sf  gr_liv_area  full_bath  totrms_abvgrd  garage_yr_blt  \
# Id
# 1761        2411         4476          3             10         1996.0
# 1768        2444         4316          3             10         1994.0
#
#       garage_cars  garage_area kitchen_qual exter_qual exter_cond garage_qual  \
# Id
# 1761            3          813           Ex         Gd         TA          TA
# 1768            3          832           Ex         Ex         TA          TA
#
#      condition_1 neighborhood
# Id
# 1761        Norm      NoRidge
# 1768        Norm      NoRidge

# %%
test_df.drop(index =[1761,1768], axis = 0, inplace=True)

# %% [markdown]
# Imputing missing values

# %%
missing_values(test_df)
# Out:
# ['mas_vnr_area', 'garage_yr_blt', 'garage_qual']

# %%
mean_vnr_area = test_df['mas_vnr_area'].mean()

# %%
mean_grg_yr = test_df['garage_yr_blt'].mean()

# %%
test_df['mas_vnr_area'].fillna(mean_vnr_area, inplace=True)
test_df['garage_yr_blt'].fillna(mean_grg_yr, inplace=True)

# %% [markdown]
# Creating dummy colummns for the categorical data

# %%
test_df = pd.get_dummies(data = test_df, columns=['kitchen_qual', 
         'exter_qual', 'exter_cond','garage_qual','condition_1', 'neighborhood'],drop_first=True)

# %%
test_df.head()
# Out:
#       overall_qual  year_built  year_remod/add  mas_vnr_area  total_bsmt_sf  \
# Id
# 2658             6        1910            1950           0.0           1020
# 2718             5        1977            1977           0.0           1967
# 2414             7        2006            2006           0.0            654
# 1989             5        1923            2006           0.0            968
# 625              6        1963            1963         247.0           1394
#
#       1st_flr_sf  gr_liv_area  full_bath  totrms_abvgrd  garage_yr_blt  ...  \
# Id                                                                      ...
# 2658         908         1928          2              9         1910.0  ...
# 2718        1967         1967          2             10         1977.0  ...
# 2414         664         1496          2              7         2006.0  ...
# 1989         968          968          1              5         1935.0  ...
# 625         1394         1394          1              6         1963.0  ...
#
#       neighborhood_NoRidge  neighborhood_NridgHt  neighborhood_OldTown  \
# Id
# 2658                     0                     0                     1
# 2718                     0                     0                     0
# 2414                     0                     0                     0
# 1989                     0                     0                     1
# 625                      0                     0                     0
#
#       neighborhood_SWISU  neighborhood_Sawyer  neighborhood_SawyerW  \
# Id
# 2658                   0                    0                     0
# 2718                   0                    1                     0
# 2414                   0                    0                     0
# 1989                   0                    0                     0
# 625                    0                    0                     0
#
#       neighborhood_Somerst  neighborhood_StoneBr  neighborhood_Timber  \
# Id
# 2658                     0                     0                    0
# 2718                     0                     0                    0
# 2414                     0                     0                    0
# 1989                     0                     0                    0
# 625                      0                     0                    0
#
#       neighborhood_Veenker
# Id
# 2658                     0
# 2718                     0
# 2414                     0
# 1989                     0
# 625                      0
#
# [5 rows x 59 columns]

# %%
## checking to see what columns are in train set but not in test set
set(complete_train_df) - set(test_df)
# Out:
# {'garage_qual_Fa', 'neighborhood_GrnHill', 'neighborhood_Landmrk', 'saleprice'}

# %%
## dropping columns in train set that aren't in test set
complete_train_df.drop(columns=['garage_qual_Fa', 'neighborhood_GrnHill', 'neighborhood_Landmrk'], inplace= True)

# %% [markdown]
# #### Saving the final testing and training dataframes

# %%
complete_train_df.to_csv('complete_train_df')
test_df.to_csv('complete_test_df')
